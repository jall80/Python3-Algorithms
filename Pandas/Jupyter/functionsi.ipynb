# %%
import pandas as pd

# %%
serie = pd.Series({'Matematicas': 8, 'Economia':6, 'Programacion': 10, 'Fisica': 5})

# %%
print(serie[serie > 6])
# Out:
# Matematicas      8
# Programacion    10
# dtype: int64

# %%
print(serie.sort_values())
# Out:
# Fisica           5
# Economia         6
# Matematicas      8
# Programacion    10
# dtype: int64

# %%
print(serie.sort_index(ascending=False))
# Out:
# Programacion    10
# Matematicas      8
# Fisica           5
# Economia         6
# dtype: int64

# %%
data = 5

# %%
serie = pd.Series(data, index=[0,1,2,3,4,5])

# %%
print(serie)
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# 5    5
# dtype: int64

# %%
data_list = ['Messi', 'Cristiano', 'Benzema']

# %%
indices = ['PSG', 'Man U', 'Real Madrid']

# %%
futbol = pd.Series(index=indices, data=data_list)

# %%
print(futbol)
# Out:
# PSG                Messi
# Man U          Cristiano
# Real Madrid      Benzema
# dtype: object
