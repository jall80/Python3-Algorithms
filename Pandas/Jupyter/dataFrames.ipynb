# %%
import pandas as pd

# %%
df = pd.DataFrame([['Maria',27], ['David', 34], ['Ana', 18], ['Jose', 17]], columns=['NOMBRE', 'EDAD'])

# %%
print(df)
# Out:
#   NOMBRE  EDAD
# 0  Maria    27
# 1  David    34
# 2    Ana    18
# 3   Jose    17

# %%
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(4,3), columns=["a", "b", 'c'])

# %%
print(df)
# Out:
#           a         b         c
# 0  0.085045 -0.458364  1.959422
# 1 -0.649803  2.802151  1.200075
# 2  0.698374  1.515525 -1.037192
# 3 -0.545126  0.183983 -0.510087
